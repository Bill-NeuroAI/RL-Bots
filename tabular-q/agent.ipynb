# %%
import jax 
import jax.numpy as jnp

# %%
#Initializing Q table
Q_table = jnp.zeros((9,4))
#starting state
s_state = 1

key = jax.random.key(0)
key, k1 = jax.random.split(key)
epsilon = 0.1


def ep_greedy():
    action_chance = jax.random.uniform(k1)
    if action_chance < epsilon:
        Q_table[state]
